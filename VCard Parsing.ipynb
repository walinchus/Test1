# %%
# !pip install vobject

# %%
# !pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in /Users/Lucia/anaconda3/lib/python3.6/site-packages (18.0)

# %%
import vobject

# %%
import os

# %%
test_filename = r'OH131240.vcf'

with open(test_filename) as source_file:
    for vcard in vobject.readComponents(source_file):
       print (vcard.email.value, vcard.fn.value)
# Out:
# sd122406@ohio.edu Susan Deaton

# %%
abfile = r'/Users/Lucia/Code/Red/'

# %%
directory_in_str = str(abfile)

# %%
directory = os.fsencode(directory_in_str)

# %%
def Get_VCards():
    for file in os.listdir(directory):
        VcardFile = os.fsdecode(file)
        #print (filename)
        if VcardFile.endswith('.vcf'): 
            #print(os.path.join(directory, filename))
            print("r"+"'"+VcardFile+"'"+",")
            #yield VcardFile
            continue
        else:
            continue
    #return VcardFile
    #print (VcardFile)

# %%
def Vcardfiles():
    for item in Get_VCards():
        yield item

# %%
Get_VCards()
# Out:
# r'OH100148.vcf',
# r'OH100295.vcf',
# r'OH1003.vcf',
# r'OH100317.vcf',
# r'OH100353.vcf',
# r'OH100379.vcf',
# r'OH100408.vcf',
# r'OH100475.vcf',
# r'OH10064.vcf',
# r'OH100976.vcf',
# r'OH101202.vcf',
# r'OH101240.vcf',
# r'OH101244.vcf',
# r'OH1013.vcf',
# r'OH1014.vcf',
# r'OH10157.vcf',
# r'OH10161.vcf',
# r'OH101616.vcf',
# r'OH101617.vcf',
# r'OH101731.vcf',
# r'OH101869.vcf',
# r'OH101935.vcf',
# r'OH10211.vcf',
# r'OH102236.vcf',
# r'OH102296.vcf',
# r'OH102310.vcf',
# r'OH102387.vcf',
# r'OH10248.vcf',
# r'OH102517.vcf',
# r'OH10264.vcf',
# r'OH102731.vcf',
# r'OH102765.vcf',
# r'OH102805.vcf',
# r'OH10290.vcf',
# r'OH102927.vcf',
# r'OH103070.vcf',
# r'OH103188.vcf',
# r'OH1032.vcf',
# r'OH103252.vcf',
# r'OH103291.vcf',
# r'OH103299.vcf',
# r'OH103300.vcf',
# r'OH103301.vcf',
# r'OH103314.vcf',
# r'OH103318.vcf',
# r'OH103322.vcf',
# r'OH103325.vcf',
# r'OH103380.vcf',
# r'OH1034.vcf',
# r'OH1035.vcf',
# r'OH10380.vcf',
# r'OH10384.vcf',
# r'OH103918.vcf',
# ...

# %%
ListOfVCards = [
r'OH100148.vcf',
r'OH100295.vcf',
r'OH1003.vcf',
r'OH100317.vcf',
r'OH100353.vcf',
r'OH100379.vcf',
r'OH100408.vcf',
r'OH100475.vcf',
r'OH10064.vcf',
r'OH100976.vcf',
r'OH101202.vcf',
r'OH101240.vcf',
r'OH101244.vcf',
r'OH1013.vcf',
r'OH1014.vcf',
r'OH10157.vcf',
r'OH10161.vcf',
r'OH101616.vcf',
r'OH101617.vcf',
r'OH101731.vcf',
r'OH101869.vcf',
r'OH101935.vcf',
r'OH10211.vcf',
r'OH102236.vcf',
r'OH102296.vcf',
r'OH102310.vcf',
r'OH102387.vcf',
r'OH10248.vcf',
r'OH102517.vcf',
r'OH10264.vcf',
r'OH102731.vcf',
r'OH102765.vcf',
r'OH102805.vcf',
r'OH10290.vcf',
r'OH102927.vcf',
r'OH103070.vcf',
r'OH103188.vcf',
r'OH1032.vcf',
r'OH103252.vcf',
r'OH103291.vcf',
r'OH103299.vcf',
r'OH103300.vcf',
r'OH103301.vcf',
r'OH103314.vcf',
r'OH103318.vcf',
r'OH103322.vcf',
r'OH103325.vcf',
r'OH103380.vcf',
r'OH1034.vcf',
r'OH1035.vcf',
r'OH10380.vcf',
r'OH10384.vcf',
r'OH103918.vcf',
r'OH104386.vcf',
r'OH104558.vcf',
r'OH104612.vcf',
r'OH10472.vcf',
r'OH10477.vcf',
r'OH104952.vcf',
r'OH105076.vcf',
r'OH105111.vcf',
r'OH10512.vcf',
r'OH105252.vcf',
r'OH105260.vcf',
r'OH10537.vcf',
r'OH105689.vcf',
r'OH10590.vcf',
r'OH105914.vcf',
r'OH10593.vcf',
r'OH10594.vcf',
r'OH10595.vcf',
r'OH10596.vcf',
r'OH10597.vcf',
r'OH105990.vcf',
r'OH10601.vcf',
r'OH10602.vcf',
r'OH106155.vcf',
r'OH106398.vcf',
r'OH106561.vcf',
r'OH106667.vcf',
r'OH107048.vcf',
r'OH107064.vcf',
r'OH107116.vcf',
r'OH107124.vcf',
r'OH107130.vcf',
r'OH107167.vcf',
r'OH107171.vcf',
r'OH107173.vcf',
r'OH107177.vcf',
r'OH107265.vcf',
r'OH107307.vcf',
r'OH107568.vcf',
r'OH10769.vcf',
r'OH107697.vcf',
r'OH10770.vcf',
r'OH10773.vcf',
r'OH107788.vcf',
r'OH10807.vcf',
r'OH108228.vcf',
r'OH108660.vcf',
r'OH108662.vcf',
r'OH108664.vcf',
r'OH108673.vcf',
r'OH108796.vcf',
r'OH109100.vcf',
r'OH10920.vcf',
r'OH109468.vcf',
r'OH109572.vcf',
r'OH10959.vcf',
r'OH109714.vcf',
r'OH109778.vcf',
r'OH109782.vcf',
r'OH109907.vcf',
r'OH11000.vcf',
r'OH110094.vcf',
r'OH11021.vcf',
r'OH110243.vcf',
r'OH110254.vcf',
r'OH110258.vcf',
r'OH110396.vcf',
r'OH110568.vcf',
r'OH110610.vcf',
r'OH110668.vcf',
r'OH110669.vcf',
r'OH110673.vcf',
r'OH110680.vcf',
r'OH110682.vcf',
r'OH11089.vcf',
r'OH111065.vcf',
r'OH111068.vcf',
r'OH11114.vcf',
r'OH111168.vcf',
r'OH111195.vcf',
r'OH111453.vcf',
r'OH111605.vcf',
r'OH11182.vcf',
r'OH111865.vcf',
r'OH111894.vcf',
r'OH111904.vcf',
r'OH112031.vcf',
r'OH11213.vcf',
r'OH112265.vcf',
r'OH112368.vcf',
r'OH112423.vcf',
r'OH112563.vcf',
r'OH112982.vcf',
r'OH113001.vcf',
r'OH113024.vcf',
r'OH11313.vcf',
r'OH11314.vcf',
r'OH11316.vcf',
r'OH11317.vcf',
r'OH11318.vcf',
r'OH11319.vcf',
r'OH113312.vcf',
r'OH113337.vcf',
r'OH113369.vcf',
r'OH113495.vcf',
r'OH113558.vcf',
r'OH113687.vcf',
r'OH113951.vcf',
r'OH113954.vcf',
r'OH113957.vcf',
r'OH113962.vcf',
r'OH113963.vcf',
r'OH114151.vcf',
r'OH114296.vcf',
r'OH114330.vcf',
r'OH11456.vcf',
r'OH11461.vcf',
r'OH11464.vcf',
r'OH11469.vcf',
r'OH11470.vcf',
r'OH11472.vcf',
r'OH114966.vcf',
r'OH11553.vcf',
r'OH115590.vcf',
r'OH115592.vcf',
r'OH115604.vcf',
r'OH115735.vcf',
r'OH115755.vcf',
r'OH11594.vcf',
r'OH115967.vcf',
r'OH115999.vcf',
r'OH11602.vcf',
r'OH11603.vcf',
r'OH11604.vcf',
r'OH116049.vcf',
r'OH116141.vcf',
r'OH116145.vcf',
r'OH116223.vcf',
r'OH116249.vcf',
r'OH116547.vcf',
r'OH11679.vcf',
r'OH117020.vcf',
r'OH117050.vcf',
r'OH117061.vcf',
r'OH117062.vcf',
r'OH117071.vcf',
r'OH11715.vcf',
r'OH11717.vcf',
r'OH11719.vcf',
r'OH11737.vcf',
r'OH117993.vcf',
r'OH118139.vcf',
r'OH11835.vcf',
r'OH118694.vcf',
r'OH118756.vcf',
r'OH118793.vcf',
r'OH118844.vcf',
r'OH118864.vcf',
r'OH118868.vcf',
r'OH11888.vcf',
r'OH11893.vcf',
r'OH118935.vcf',
r'OH11899.vcf',
r'OH11960.vcf',
r'OH11961.vcf',
r'OH119612.vcf',
r'OH11962.vcf',
r'OH119633.vcf',
r'OH119635.vcf',
r'OH119636.vcf',
r'OH119802.vcf',
r'OH120076.vcf',
r'OH120163.vcf',
r'OH120185.vcf',
r'OH120190.vcf',
r'OH12027.vcf',
r'OH12062.vcf',
r'OH120683.vcf',
r'OH120685.vcf',
r'OH121136.vcf',
r'OH121146.vcf',
r'OH121225.vcf',
r'OH121290.vcf',
r'OH121330.vcf',
r'OH121362.vcf',
r'OH121363.vcf',
r'OH121453.vcf',
r'OH121464.vcf',
r'OH121469.vcf',
r'OH121471.vcf',
r'OH121472.vcf',
r'OH121530.vcf',
r'OH121602.vcf',
r'OH12165.vcf',
r'OH121680.vcf',
r'OH12185.vcf',
r'OH122253.vcf',
r'OH122381.vcf',
r'OH122397.vcf',
r'OH122402.vcf',
r'OH122494.vcf',
r'OH12276.vcf',
r'OH12280.vcf',
r'OH12282.vcf',
r'OH123002.vcf',
r'OH123093.vcf',
r'OH123167.vcf',
r'OH12338.vcf',
r'OH12342.vcf',
r'OH12358.vcf',
r'OH123856.vcf',
r'OH123937.vcf',
r'OH123946.vcf',
r'OH124052.vcf',
r'OH124068.vcf',
r'OH124320.vcf',
r'OH124608.vcf',
r'OH124623.vcf',
r'OH124653.vcf',
r'OH124713.vcf',
r'OH12488.vcf',
r'OH124914.vcf',
r'OH124957.vcf',
r'OH12578.vcf',
r'OH126024.vcf',
r'OH126039.vcf',
r'OH126040.vcf',
r'OH12620.vcf',
r'OH126303.vcf',
r'OH126441.vcf',
r'OH126482.vcf',
r'OH126603.vcf',
r'OH12680.vcf',
r'OH12756.vcf',
r'OH12759.vcf',
r'OH12783.vcf',
r'OH12807.vcf',
r'OH128210.vcf',
r'OH12823.vcf',
r'OH128318.vcf',
r'OH128421.vcf',
r'OH128506.vcf',
r'OH128539.vcf',
r'OH128663.vcf',
r'OH128734.vcf',
r'OH128843.vcf',
r'OH128848.vcf',
r'OH12898.vcf',
r'OH129043.vcf',
r'OH12941.vcf',
r'OH12942.vcf',
r'OH12952.vcf',
r'OH13010.vcf',
r'OH13020.vcf',
r'OH130323.vcf',
r'OH130664.vcf',
r'OH130858.vcf',
r'OH13097.vcf',
r'OH13099.vcf',
r'OH131201.vcf',
r'OH131240.vcf',
r'OH13191.vcf',
r'OH13192.vcf',
r'OH13202.vcf',
r'OH13231.vcf',
r'OH13233.vcf',
r'OH132529.vcf',
r'OH132552.vcf',
r'OH132571.vcf',
r'OH132588.vcf',
r'OH132596.vcf',
r'OH132678.vcf',
r'OH132684.vcf',
r'OH132810.vcf',
r'OH132903.vcf',
r'OH133162.vcf',
r'OH133527.vcf',
r'OH13364.vcf',
r'OH13365.vcf',
r'OH13367.vcf',
r'OH13368.vcf',
r'OH13429.vcf',
r'OH13451.vcf',
r'OH13500.vcf',
r'OH13576.vcf',
r'OH13607.vcf',
r'OH13608.vcf',
r'OH13624.vcf',
r'OH13705.vcf',
r'OH13792.vcf',
r'OH13793.vcf',
r'OH13834.vcf',
r'OH13841.vcf',
r'OH13940.vcf',
r'OH13960.vcf',
r'OH13962.vcf',
r'OH13963.vcf',
r'OH14002.vcf',
r'OH14025.vcf',
r'OH14074.vcf',
r'OH14075.vcf',
r'OH14078.vcf',
r'OH14080.vcf',
r'OH14082.vcf',
r'OH14087.vcf',
r'OH14096.vcf',
r'OH14120.vcf',
r'OH14209.vcf',
r'OH14210.vcf',
r'OH14212.vcf',
r'OH14213.vcf',
r'OH14215.vcf',
r'OH14295.vcf',
r'OH14343.vcf',
r'OH14344.vcf',
r'OH14345.vcf',
r'OH14348.vcf',
r'OH14376.vcf',
r'OH14379.vcf',
r'OH14414.vcf',
r'OH14514.vcf',
r'OH14557.vcf',
r'OH14571.vcf',
r'OH14641.vcf',
r'OH14682.vcf',
r'OH14689.vcf',
r'OH14713.vcf',
r'OH14743.vcf',
r'OH14757.vcf',
r'OH14766.vcf',
r'OH14822.vcf',
r'OH14830.vcf',
r'OH14832.vcf',
r'OH14972.vcf',
r'OH14994.vcf',
r'OH15096.vcf',
r'OH15143.vcf',
r'OH15209.vcf',
r'OH15210.vcf',
r'OH15212.vcf',
r'OH15213.vcf',
r'OH15240.vcf',
r'OH15311.vcf',
r'OH15312.vcf',
r'OH15356.vcf',
r'OH15462.vcf',
r'OH15521.vcf',
r'OH15575.vcf',
r'OH15680.vcf',
r'OH15702.vcf',
r'OH15704.vcf',
r'OH15747.vcf',
r'OH15749.vcf',
r'OH15799.vcf',
r'OH15845.vcf',
r'OH15850.vcf',
r'OH15851.vcf',
r'OH15902.vcf',
r'OH15931.vcf',
r'OH15990.vcf',
r'OH16019.vcf',
r'OH16042.vcf',
r'OH16092.vcf',
r'OH16156.vcf',
r'OH16173.vcf',
r'OH16229.vcf',
r'OH16285.vcf',
r'OH16323.vcf',
r'OH16371.vcf',
r'OH16444.vcf',
r'OH16445.vcf',
r'OH16490.vcf',
r'OH16603.vcf',
r'OH16674.vcf',
r'OH16788.vcf',
r'OH16789.vcf',
r'OH16815.vcf',
r'OH16912.vcf',
r'OH16934.vcf',
r'OH16936.vcf',
r'OH17001.vcf',
r'OH17004.vcf',
r'OH17075.vcf',
r'OH17077.vcf',
r'OH17079.vcf',
r'OH17080.vcf',
r'OH17154.vcf',
r'OH17155.vcf',
r'OH17156.vcf',
r'OH17247.vcf',
r'OH17280.vcf',
r'OH17374.vcf',
r'OH17393.vcf',
r'OH17510.vcf',
r'OH17534.vcf',
r'OH17598.vcf',
r'OH17599.vcf',
r'OH17653.vcf',
r'OH17672.vcf',
r'OH17700.vcf',
r'OH17701.vcf',
r'OH17773.vcf',
r'OH17818.vcf',
r'OH17847.vcf',
r'OH17917.vcf',
r'OH17966.vcf',
r'OH17996.vcf',
r'OH18149.vcf',
r'OH18185.vcf',
r'OH18319.vcf',
r'OH18320.vcf',
r'OH18463.vcf',
r'OH18575.vcf',
r'OH18633.vcf',
r'OH18814.vcf',
r'OH18969.vcf',
r'OH19101.vcf',
r'OH19138.vcf',
r'OH19179.vcf',
r'OH19203.vcf',
r'OH19380.vcf',
r'OH19441.vcf',
r'OH19509.vcf',
r'OH19510.vcf',
r'OH19511.vcf',
r'OH19538.vcf',
r'OH19572.vcf',
r'OH19672.vcf',
r'OH19673.vcf',
r'OH19684.vcf',
r'OH19721.vcf',
r'OH19723.vcf',
r'OH19724.vcf',
r'OH19725.vcf',
r'OH19792.vcf',
r'OH19833.vcf',
r'OH19882.vcf',
r'OH19883.vcf',
r'OH19885.vcf',
r'OH19934.vcf',
r'OH19938.vcf',
r'OH2.vcf',
r'OH20066.vcf',
r'OH20068.vcf',
r'OH20154.vcf',
r'OH20303.vcf',
r'OH20355.vcf',
r'OH20356.vcf',
r'OH20506.vcf',
r'OH20562.vcf',
r'OH20597.vcf',
r'OH20727.vcf',
r'OH20813.vcf',
r'OH20814.vcf',
r'OH20887.vcf',
r'OH21142.vcf',
r'OH21217.vcf',
r'OH21218.vcf',
r'OH21225.vcf',
r'OH21271.vcf',
r'OH21272.vcf',
r'OH21273.vcf',
r'OH21324.vcf',
r'OH21357.vcf',
r'OH21358.vcf',
r'OH21388.vcf',
r'OH21446.vcf',
r'OH21512.vcf',
r'OH21513.vcf',
r'OH21600.vcf',
r'OH21631.vcf',
r'OH21633.vcf',
r'OH21799.vcf',
r'OH21806.vcf',
r'OH21865.vcf',
r'OH21914.vcf',
r'OH21919.vcf',
r'OH21993.vcf',
r'OH22077.vcf',
r'OH22080.vcf',
r'OH22149.vcf',
r'OH22298.vcf',
r'OH22299.vcf',
r'OH22347.vcf',
r'OH22349.vcf',
r'OH22375.vcf',
r'OH22403.vcf',
r'OH22456.vcf',
r'OH22505.vcf',
r'OH2252.vcf',
r'OH22647.vcf',
r'OH22726.vcf',
r'OH22785.vcf',
r'OH22787.vcf',
r'OH22789.vcf',
r'OH22792.vcf',
r'OH22800.vcf',
r'OH22813.vcf',
r'OH22816.vcf',
r'OH22817.vcf',
r'OH22826.vcf',
r'OH22828.vcf',
r'OH22831.vcf',
r'OH23004.vcf',
r'OH23131.vcf',
r'OH23422.vcf',
r'OH23449.vcf',
r'OH23537.vcf',
r'OH23538.vcf',
r'OH23540.vcf',
r'OH23543.vcf',
r'OH23545.vcf',
r'OH23547.vcf',
r'OH23838.vcf',
r'OH23999.vcf',
r'OH24019.vcf',
r'OH24021.vcf',
r'OH24022.vcf',
r'OH24025.vcf',
r'OH24029.vcf',
r'OH24030.vcf',
r'OH24035.vcf',
r'OH24041.vcf',
r'OH24042.vcf',
r'OH24047.vcf',
r'OH24572.vcf',
r'OH24618.vcf',
r'OH24786.vcf',
r'OH24802.vcf',
r'OH24882.vcf',
r'OH24884.vcf',
r'OH24887.vcf',
r'OH24893.vcf',
r'OH24895.vcf',
r'OH24896.vcf',
r'OH25181.vcf',
r'OH25451.vcf',
r'OH25453.vcf',
r'OH25457.vcf',
r'OH25465.vcf',
r'OH25467.vcf',
r'OH25475.vcf',
r'OH25476.vcf',
r'OH25477.vcf',
r'OH25486.vcf',
r'OH25488.vcf',
r'OH25741.vcf',
r'OH25975.vcf',
r'OH26059.vcf',
r'OH26078.vcf',
r'OH26183.vcf',
r'OH26194.vcf',
r'OH26229.vcf',
r'OH26264.vcf',
r'OH26299.vcf',
r'OH26332.vcf',
r'OH26338.vcf',
r'OH26500.vcf',
r'OH26529.vcf',
r'OH26577.vcf',
r'OH26699.vcf',
r'OH26770.vcf',
r'OH26778.vcf',
r'OH26779.vcf',
r'OH26784.vcf',
r'OH26785.vcf',
r'OH26787.vcf',
r'OH26789.vcf',
r'OH26790.vcf',
r'OH26793.vcf',
r'OH26795.vcf',
r'OH26797.vcf',
r'OH26802.vcf',
r'OH26810.vcf',
r'OH26811.vcf',
r'OH27166.vcf',
r'OH27250.vcf',
r'OH27312.vcf',
r'OH27318.vcf',
r'OH27324.vcf',
r'OH27345.vcf',
r'OH27428.vcf',
r'OH27460.vcf',
r'OH27462.vcf',
r'OH27465.vcf',
r'OH27471.vcf',
r'OH27473.vcf',
r'OH27685.vcf',
r'OH27693.vcf',
r'OH27949.vcf',
r'OH27993.vcf',
r'OH28086.vcf',
r'OH28092.vcf',
r'OH28109.vcf',
r'OH28236.vcf',
r'OH28237.vcf',
r'OH28239.vcf',
r'OH28245.vcf',
r'OH28246.vcf',
r'OH28247.vcf',
r'OH28256.vcf',
r'OH28259.vcf',
r'OH28263.vcf',
r'OH28265.vcf',
r'OH28270.vcf',
r'OH28272.vcf',
r'OH28278.vcf',
r'OH28281.vcf',
r'OH28284.vcf',
r'OH28288.vcf',
r'OH28417.vcf',
r'OH2874.vcf',
r'OH28897.vcf',
r'OH28902.vcf',
r'OH29009.vcf',
r'OH29011.vcf',
r'OH29012.vcf',
r'OH29013.vcf',
r'OH29015.vcf',
r'OH29037.vcf',
r'OH29051.vcf',
r'OH29208.vcf',
r'OH29449.vcf',
r'OH29455.vcf',
r'OH29460.vcf',
r'OH29462.vcf',
r'OH29468.vcf',
r'OH29479.vcf',
r'OH29482.vcf',
r'OH29485.vcf',
r'OH29491.vcf',
r'OH30042.vcf',
r'OH30077.vcf',
r'OH30149.vcf',
r'OH30161.vcf',
r'OH30467.vcf',
r'OH30685.vcf',
r'OH30686.vcf',
r'OH30687.vcf',
r'OH30693.vcf',
r'OH30696.vcf',
r'OH30702.vcf',
r'OH30704.vcf',
r'OH30715.vcf',
r'OH30724.vcf',
r'OH30951.vcf',
r'OH31223.vcf',
r'OH31290.vcf',
r'OH31345.vcf',
r'OH31346.vcf',
r'OH31348.vcf',
r'OH31349.vcf',
r'OH31351.vcf',
r'OH315.vcf',
r'OH31545.vcf',
r'OH31671.vcf',
r'OH31676.vcf',
r'OH31677.vcf',
r'OH31681.vcf',
r'OH31683.vcf',
r'OH31685.vcf',
r'OH31688.vcf',
r'OH31692.vcf',
r'OH31693.vcf',
r'OH31695.vcf',
r'OH31697.vcf',
r'OH31705.vcf',
r'OH31709.vcf',
r'OH31712.vcf',
r'OH31714.vcf',
r'OH3181.vcf',
r'OH32318.vcf',
r'OH32319.vcf',
r'OH32323.vcf',
r'OH32367.vcf',
r'OH32616.vcf',
r'OH32620.vcf',
r'OH32622.vcf',
r'OH32624.vcf',
r'OH32645.vcf',
r'OH32845.vcf',
r'OH32972.vcf',
r'OH33022.vcf',
r'OH33126.vcf',
r'OH33187.vcf',
r'OH33196.vcf',
r'OH33213.vcf',
r'OH33250.vcf',
r'OH33359.vcf',
r'OH33369.vcf',
r'OH33402.vcf',
r'OH33444.vcf',
r'OH33462.vcf',
r'OH33551.vcf',
r'OH33687.vcf',
r'OH33690.vcf',
r'OH33691.vcf',
r'OH33693.vcf',
r'OH33701.vcf',
r'OH33707.vcf',
r'OH33714.vcf',
r'OH33716.vcf',
r'OH33718.vcf',
r'OH33726.vcf',
r'OH33736.vcf',
r'OH33744.vcf',
r'OH33747.vcf',
r'OH33748.vcf',
r'OH33940.vcf',
r'OH34013.vcf',
r'OH34067.vcf',
r'OH34325.vcf',
r'OH34452.vcf',
r'OH34455.vcf',
r'OH34566.vcf',
r'OH34582.vcf',
r'OH34670.vcf',
r'OH34699.vcf',
r'OH34703.vcf',
r'OH34768.vcf',
r'OH34831.vcf',
r'OH34918.vcf',
r'OH34987.vcf',
r'OH34999.vcf',
r'OH35016.vcf',
r'OH35141.vcf',
r'OH35153.vcf',
r'OH35394.vcf',
r'OH35546.vcf',
r'OH35566.vcf',
r'OH35593.vcf',
r'OH35615.vcf',
r'OH35632.vcf',
r'OH35663.vcf',
r'OH35724.vcf',
r'OH35734.vcf',
r'OH35743.vcf',
r'OH35822.vcf',
r'OH35873.vcf',
r'OH35918.vcf',
r'OH35923.vcf',
r'OH36135.vcf',
r'OH36196.vcf',
r'OH36200.vcf',
r'OH36336.vcf',
r'OH36393.vcf',
r'OH36396.vcf',
r'OH36555.vcf',
r'OH36586.vcf',
r'OH36726.vcf',
r'OH3677.vcf',
r'OH36771.vcf',
r'OH36800.vcf',
r'OH37057.vcf',
r'OH37172.vcf',
r'OH37349.vcf',
r'OH37447.vcf',
r'OH37526.vcf',
r'OH37569.vcf',
r'OH37703.vcf',
r'OH37715.vcf',
r'OH37720.vcf',
r'OH37729.vcf',
r'OH37893.vcf',
r'OH37910.vcf',
r'OH37933.vcf',
r'OH38094.vcf',
r'OH38145.vcf',
r'OH38285.vcf',
r'OH38408.vcf',
r'OH38532.vcf',
r'OH38565.vcf',
r'OH38588.vcf',
r'OH38602.vcf',
r'OH38674.vcf',
r'OH38713.vcf',
r'OH38769.vcf',
r'OH38778.vcf',
r'OH38905.vcf',
r'OH38983.vcf',
r'OH39013.vcf',
r'OH39185.vcf',
r'OH39280.vcf',
r'OH39283.vcf',
r'OH39314.vcf',
r'OH39347.vcf',
r'OH39359.vcf',
r'OH39527.vcf',
r'OH39531.vcf',
r'OH39555.vcf',
r'OH39559.vcf',
r'OH39560.vcf',
r'OH39562.vcf',
r'OH39563.vcf',
r'OH39564.vcf',
r'OH39633.vcf',
r'OH39640.vcf',
r'OH39651.vcf',
r'OH39799.vcf',
r'OH39869.vcf',
r'OH39877.vcf',
r'OH39882.vcf',
r'OH40126.vcf',
r'OH40129.vcf',
r'OH40146.vcf',
r'OH40148.vcf',
r'OH40174.vcf',
r'OH40217.vcf',
r'OH40244.vcf',
r'OH40347.vcf',
r'OH40462.vcf',
r'OH4054.vcf',
r'OH40584.vcf',
r'OH40668.vcf',
r'OH40775.vcf',
r'OH40888.vcf',
r'OH40895.vcf',
r'OH40914.vcf',
r'OH40979.vcf',
r'OH41001.vcf',
r'OH41032.vcf',
r'OH41136.vcf',
r'OH41168.vcf',
r'OH41171.vcf',
r'OH41174.vcf',
r'OH41181.vcf',
r'OH41680.vcf',
r'OH41778.vcf',
r'OH41838.vcf',
r'OH41919.vcf',
r'OH41955.vcf',
r'OH41990.vcf',
r'OH42061.vcf',
r'OH4207.vcf',
r'OH42086.vcf',
r'OH42151.vcf',
r'OH42233.vcf',
r'OH42390.vcf',
r'OH42432.vcf',
r'OH42464.vcf',
r'OH42473.vcf',
r'OH42689.vcf',
r'OH42695.vcf',
r'OH43080.vcf',
r'OH43087.vcf',
r'OH43106.vcf',
r'OH43313.vcf',
r'OH4375.vcf',
r'OH43768.vcf',
r'OH43777.vcf',
r'OH4378.vcf',
r'OH43788.vcf',
r'OH43792.vcf',
r'OH43802.vcf',
r'OH43841.vcf',
r'OH43884.vcf',
r'OH43989.vcf',
r'OH43991.vcf',
r'OH44010.vcf',
r'OH44014.vcf',
r'OH44154.vcf',
r'OH44246.vcf',
r'OH44380.vcf',
r'OH44620.vcf',
r'OH44630.vcf',
r'OH4464.vcf',
r'OH44669.vcf',
r'OH44757.vcf',
r'OH44791.vcf',
r'OH44910.vcf',
r'OH44937.vcf',
r'OH45111.vcf',
r'OH45214.vcf',
r'OH4525.vcf',
r'OH45254.vcf',
r'OH453.vcf',
r'OH45438.vcf',
r'OH45518.vcf',
r'OH45741.vcf',
r'OH45743.vcf',
r'OH45774.vcf',
r'OH45775.vcf',
r'OH45956.vcf',
r'OH46021.vcf',
r'OH46022.vcf',
r'OH46045.vcf',
r'OH46051.vcf',
r'OH46117.vcf',
r'OH46136.vcf',
r'OH4617.vcf',
r'OH46177.vcf',
r'OH46186.vcf',
r'OH46253.vcf',
r'OH46260.vcf',
r'OH46285.vcf',
r'OH46288.vcf',
r'OH46349.vcf',
r'OH46376.vcf',
r'OH46406.vcf',
r'OH46494.vcf',
r'OH46534.vcf',
r'OH46549.vcf',
r'OH46563.vcf',
r'OH46617.vcf',
r'OH46620.vcf',
r'OH46648.vcf',
r'OH46670.vcf',
r'OH46739.vcf',
r'OH46970.vcf',
r'OH4700.vcf',
r'OH4701.vcf',
r'OH47012.vcf',
r'OH47044.vcf',
r'OH47134.vcf',
r'OH47248.vcf',
r'OH47290.vcf',
r'OH47457.vcf',
r'OH47556.vcf',
r'OH47586.vcf',
r'OH4759.vcf',
r'OH47642.vcf',
r'OH47655.vcf',
r'OH47675.vcf',
r'OH47693.vcf',
r'OH47764.vcf',
r'OH47765.vcf',
r'OH47850.vcf',
r'OH47856.vcf',
r'OH47860.vcf',
r'OH47861.vcf',
r'OH47869.vcf',
r'OH47871.vcf',
r'OH48132.vcf',
r'OH48212.vcf',
r'OH4848.vcf',
r'OH4898.vcf',
r'OH4967.vcf',
r'OH4973.vcf',
r'OH4993.vcf',
r'OH50046.vcf',
r'OH5052.vcf',
r'OH5158.vcf',
r'OH5182.vcf',
r'OH5193.vcf',
r'OH5218.vcf',
r'OH5287.vcf',
r'OH5351.vcf',
r'OH5426.vcf',
r'OH5427.vcf',
r'OH5481.vcf',
r'OH5537.vcf',
r'OH55813.vcf',
r'OH5610.vcf',
r'OH5668.vcf',
r'OH57286.vcf',
r'OH5810.vcf',
r'OH58251.vcf',
r'OH58744.vcf',
r'OH58751.vcf',
r'OH59189.vcf',
r'OH59200.vcf',
r'OH59206.vcf',
r'OH59588.vcf',
r'OH59591.vcf',
r'OH59598.vcf',
r'OH5969.vcf',
r'OH6002.vcf',
r'OH60308.vcf',
r'OH60310.vcf',
r'OH6042.vcf',
r'OH6051.vcf',
r'OH6052.vcf',
r'OH60800.vcf',
r'OH60805.vcf',
r'OH60979.vcf',
r'OH6217.vcf',
r'OH6265.vcf',
r'OH62816.vcf',
r'OH63003.vcf',
r'OH63005.vcf',
r'OH63265.vcf',
r'OH63279.vcf',
r'OH6361.vcf',
r'OH6401.vcf',
r'OH64703.vcf',
r'OH6682.vcf',
r'OH6752.vcf',
r'OH6820.vcf',
r'OH68219.vcf',
r'OH68225.vcf',
r'OH6871.vcf',
r'OH6894.vcf',
r'OH6924.vcf',
r'OH7006.vcf',
r'OH7098.vcf',
r'OH71086.vcf',
r'OH7167.vcf',
r'OH72602.vcf',
r'OH7338.vcf',
r'OH7396.vcf',
r'OH7409.vcf',
r'OH7416.vcf',
r'OH7432.vcf',
r'OH7434.vcf',
r'OH7435.vcf',
r'OH7482.vcf',
r'OH7483.vcf',
r'OH7555.vcf',
r'OH7607.vcf',
r'OH7748.vcf',
r'OH7871.vcf',
r'OH7931.vcf',
r'OH7934.vcf',
r'OH7935.vcf',
r'OH79704.vcf',
r'OH79739.vcf',
r'OH80103.vcf',
r'OH8035.vcf',
r'OH8057.vcf',
r'OH8058.vcf',
r'OH81202.vcf',
r'OH8131.vcf',
r'OH815.vcf',
r'OH8178.vcf',
r'OH820.vcf',
r'OH825.vcf',
r'OH8250.vcf',
r'OH8251.vcf',
r'OH8253.vcf',
r'OH8316.vcf',
r'OH834.vcf',
r'OH8341.vcf',
r'OH836.vcf',
r'OH837.vcf',
r'OH838.vcf',
r'OH83804.vcf',
r'OH83985.vcf',
r'OH84037.vcf',
r'OH84116.vcf',
r'OH84319.vcf',
r'OH8437.vcf',
r'OH8440.vcf',
r'OH8442.vcf',
r'OH84539.vcf',
r'OH84606.vcf',
r'OH84608.vcf',
r'OH84778.vcf',
r'OH84787.vcf',
r'OH84851.vcf',
r'OH84932.vcf',
r'OH8511.vcf',
r'OH8513.vcf',
r'OH8514.vcf',
r'OH85144.vcf',
r'OH8515.vcf',
r'OH85278.vcf',
r'OH854.vcf',
r'OH85521.vcf',
r'OH85621.vcf',
r'OH85789.vcf',
r'OH85833.vcf',
r'OH8603.vcf',
r'OH8606.vcf',
r'OH8607.vcf',
r'OH86212.vcf',
r'OH86663.vcf',
r'OH86668.vcf',
r'OH8673.vcf',
r'OH868.vcf',
r'OH86818.vcf',
r'OH86864.vcf',
r'OH86937.vcf',
r'OH87044.vcf',
r'OH87104.vcf',
r'OH87105.vcf',
r'OH87168.vcf',
r'OH8727.vcf',
r'OH87314.vcf',
r'OH87430.vcf',
r'OH87452.vcf',
r'OH87473.vcf',
r'OH8750.vcf',
r'OH8760.vcf',
r'OH87970.vcf',
r'OH88093.vcf',
r'OH88381.vcf',
r'OH88394.vcf',
r'OH8842.vcf',
r'OH88684.vcf',
r'OH8880.vcf',
r'OH889.vcf',
r'OH8897.vcf',
r'OH88998.vcf',
r'OH8900.vcf',
r'OH89001.vcf',
r'OH89002.vcf',
r'OH8909.vcf',
r'OH894.vcf',
r'OH8950.vcf',
r'OH89592.vcf',
r'OH89896.vcf',
r'OH899.vcf',
r'OH89962.vcf',
r'OH90036.vcf',
r'OH90119.vcf',
r'OH90128.vcf',
r'OH9023.vcf',
r'OH9030.vcf',
r'OH90563.vcf',
r'OH90846.vcf',
r'OH90870.vcf',
r'OH90893.vcf',
r'OH90897.vcf',
r'OH91105.vcf',
r'OH91114.vcf',
r'OH91124.vcf',
r'OH9129.vcf',
r'OH9131.vcf',
r'OH91524.vcf',
r'OH91829.vcf',
r'OH920.vcf',
r'OH92215.vcf',
r'OH92244.vcf',
r'OH924.vcf',
r'OH9246.vcf',
r'OH9247.vcf',
r'OH927.vcf',
r'OH93005.vcf',
r'OH93038.vcf',
r'OH93395.vcf',
r'OH93627.vcf',
r'OH93851.vcf',
r'OH94241.vcf',
r'OH9431.vcf',
r'OH94316.vcf',
r'OH9437.vcf',
r'OH94370.vcf',
r'OH9447.vcf',
r'OH9477.vcf',
r'OH94873.vcf',
r'OH95127.vcf',
r'OH957.vcf',
r'OH95789.vcf',
r'OH95883.vcf',
r'OH95968.vcf',
r'OH9602.vcf',
r'OH96028.vcf',
r'OH9605.vcf',
r'OH96099.vcf',
r'OH96254.vcf',
r'OH96338.vcf',
r'OH96375.vcf',
r'OH96498.vcf',
r'OH965.vcf',
r'OH96531.vcf',
r'OH96723.vcf',
r'OH96760.vcf',
r'OH96768.vcf',
r'OH96918.vcf',
r'OH96939.vcf',
r'OH96955.vcf',
r'OH97011.vcf',
r'OH97013.vcf',
r'OH9718.vcf',
r'OH97196.vcf',
r'OH9720.vcf',
r'OH97222.vcf',
r'OH974.vcf',
r'OH97433.vcf',
r'OH97788.vcf',
r'OH9824.vcf',
r'OH98414.vcf',
r'OH9852.vcf',
r'OH98821.vcf',
r'OH98942.vcf',
r'OH99071.vcf',
r'OH99152.vcf',
r'OH99205.vcf',
r'OH99376.vcf',
r'OH99441.vcf',
r'OH99660.vcf',
r'OH99671.vcf',
r'OH997.vcf',
r'OH99709.vcf',
r'OH99743.vcf']

# %%
def PrintingEmailInfo():
    for VCFfilename in ListOfVCards:
        #print ("r'%s'" % ListOfVCards)
        with open(VCFfilename) as source_file:
            for vcard in vobject.readComponents(source_file):
                try:
                    print (vcard.email.value, vcard.fn.value)
                except AttributeError:
                    continue
                except KeyError:
                    continue

# %%
PrintingEmailInfo()
# Out:
# julie@dreher-law.com Julieann Dreher
# rdelliott@vorys.com Ryan Elliott
# dickeichhold@gmail.com Paul Eichhold
# tracy.dickens@ohioattorneygeneral.gov Tracy Dickens
# hae@hurtukdaroff.com Haley Eppler
# jeskridge@fmelawohio.com James Eskridge
# jdemars@fieldshowell.com Jocelyn Cubbon DeMars
# nendsley@ssdlaw.com Nick Endsley
# wdues@dueslaw.com Wilfrid Dues
# edurnell@lovettlawoffice.com Elizabeth Durnell
# debtreliefsoon@gmail.com Cynthia Daugherty
# michael.paul.dailey@gmail.com Michael Dailey
# lauren@boucherandboucher.com Lauren Davenport
# tb@eldredge.com Barbara Eldredge
# rozjer50@gmail.com Jerome Ellerin
# cdelaney@mpdwlaw.com Cormac DeLaney
# jembleton@mggmlpa.com Jeffrey Embleton
# jdebra@clp-law.com Joshua DeBra
# ryan@debra-law.com Ryan DeBra
# matthewdixon@att.net Matthew Dixon
# jdortch@kravitzllc.com Justin Dortch
# joe.esmont@gmail.com Joseph Esmont
# broth@elkandelk.com Arthur Elk
# dean@ccj.com Jacob Dean
# Justin.Eneorji@gmail.com Justin Eneorji
# ...

# %%
PrettyList(Get_VCards())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-dca4478d6dec> in <module>()
# ----> 1 PrettyList(Get_VCards())
#
# NameError: name 'PrettyList' is not defined

# %%
print (words)

# %%
print (this[14])
